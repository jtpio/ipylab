# %%
# %pip install -q ipylab

# %% [markdown]
# # Generic methods
#
# In cases where a method hasn't been implemented in the Python `JupyterFrontEnd`, it may be possible to perform the operation using one of the generic functions.
#
# * schedule_operation('FE_execute', ...)
# * execute_method
# * listAttributes - to list available attributes
# * listMethods (listAttributes tweaked to list only the methods)
# * get_attribute

# %% [markdown]
# Note: This notebook should be run one line at a time waiting for each cell to return before running the next cell.

# %%
import ipylab

app = ipylab.JupyterFrontEnd()

# %%
t = app.listMethods("app.shell", depth=2)
# Out:
# {'ipylab_BE': '83a513b1-0ab3-443f-9521-b740be0b8cd3', 'operation': 'FE_execute', 'kwgs': {'FE_execute': {'mode': 'execute_method', 'kwgs': {'method': 'listAttributes'}}, 'args': ('app.shell', 'function', 2)}, 'transform': <TransformMode.raw: 'raw'>}

# %%
methods = t.result()
methods
# Out:
# ['node',
#  'constructor',
#  'activeChanged',
#  'activeWidget',
#  'addButtonEnabled',
#  'addRequested',
#  'currentChanged',
#  'currentPath',
#  'currentPathChanged',
#  'currentWidget',
#  'layoutModified',
#  'leftCollapsed',
#  'rightCollapsed',
#  'presentationMode',
#  'mode',
#  'modeChanged',
#  'restored',
#  'translator',
#  'userLayout',
#  'activateById',
#  'activateNextTab',
#  'activatePreviousTab',
#  'activateNextTabBar',
#  'activatePreviousTabBar',
#  'add',
#  'move',
#  'collapseLeft',
#  'collapseRight',
#  'dispose',
#  'expandLeft',
#  'expandRight',
#  'closeAll',
#  'isSideTabBarVisible',
#  'isTopInSimpleModeVisible',
#  'isEmpty',
#  'restoreLayout',
#  'saveLayout',
#  'toggleTopInSimpleModeVisibility',
#  'toggleSideTabBarVisibility',
#  'updateConfig',
#  'widgets',
#  'onAfterAttach']

# %% [markdown]
# Some of the methods above have already been implemented in 'app.shell' on the Python object. And if you look at the code you'll see these methods use the *generic* method (techincally, it is a subclass which inserts `'shell.'` infront of the path in the method `execute_method` to match it's level in the JupyterFrontend Object. So basically the same function call is sent to the frontend.
#
# In case you're interested, the custom part of message sent to the frontend looks like this:
#
# ```python
# {
#     "ipylab_BE": "83a513b1-0ab3-443f-9521-b740be0b8cd3, # unique per message
#     "operation": "FE_execute",
#     "kwgs": {
#         "FE_execute": {"mode": "execute_method", "kwgs": {"method": "listAttributes"}},
#         "args": ("app.shell", "function", 2),
#     },
#     "transform": "raw",
# }
#
#
# ```

# %%
"expandLeft" in methods  # Confirm the messege is in the list
# Out:
# True

# %%
# The source code

import inspect

print(inspect.getsource(app.shell.expandLeft))
# Out:
#     def expandLeft(self) -> asyncio.Task:
#         return self.execute_method("expandLeft")

# %%
t = app.shell.expandLeft()

# %%
t = app.execute_method("shell.expandLeft")

# %% [markdown]
# ## Nested attributes
#
# The app backend is not an exact replica of the object on the frontend (JS). If there is a nested object on the backend, the object root is modified so that it points to the root of the object on the frontend. That said, all objects provide direct access to the 'app', but methods called relative to `app` on the frontend should be called with `app` on the backend.

# %%
app.shell.app is app
# Out:
# True

# %%
t = app.listAttributes(depth=2)

# %%
attributes = t.result()
attributes
# Out:
# {'string': ['cid', 'model_id', '_kernelId', 'name', 'module'],
#  'object': ['attributes',
#   '_previousAttributes',
#   'changed',
#   '_buffered_state_diff_synced',
#   '_expectedEchoMsgIds',
#   '_attrsToUpdate',
#   'widget_manager',
#   'views',
#   'state_change',
#   '_state_lock',
#   '_msg_buffer',
#   '_msg_buffer_callbacks',
#   '_buffered_state_diff',
#   'comm',
#   '_pending_backend_operation_callbacks',
#   '_events'],
#  'boolean': ['_changing', '_pending', '_closed', '_comm_live'],
#  'undefined': ['id'],
#  'number': ['_pending_msgs']}

# %%
t = app.listAttributes("app.shell", depth=2)

# %% [markdown]
# # Session Manager

# %%
from ipylab import JupyterFrontEnd
app = JupyterFrontEnd()

# %%
dir(app.comm.kernel
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abort_queues',
#  '_aborting',
#  '_add_notifiers',
#  '_allow_stdin',
#  '_at_shutdown',
#  '_cancel_on_sigint',
#  '_config_changed',
#  '_cross_validation_lock',
#  '_darwin_app_nap',
#  '_default_ident',
#  '_dispatch_abort',
#  '_execute_sleep',
#  '_experimental_do_complete',
#  '_find_my_config',
#  '_forward_input',
#  '_input_request',
#  '_instance',
#  '_load_config',
#  '_log_default',
#  '_message_counter',
#  '_message_counter_default',
#  '_no_raw_input',
#  '_notify_trait',
#  '_parent_header',
# ...

# %%
app.sessions.list_sessions()
# Out:
# [{'id': 'bcaceaf0-9120-4cb8-8a5b-e31b7d2e7c3b',
#   'path': 'examples/commands.ipynb',
#   'name': 'commands.ipynb',
#   'type': 'notebook',
#   'kernel': {'id': '4f6b9bd4-0fed-4f91-b38d-af4e32739c8c',
#    'name': 'python3',
#    'last_activity': '2020-05-27T16:55:48.843717Z',
#    'execution_state': 'idle',
#    'connections': 1},
#   'notebook': {'path': 'examples/commands.ipynb', 'name': 'commands.ipynb'}},
#  {'id': '4f9771ea-85f6-4b8b-875c-a735593713e2',
#   'path': 'examples/Untitled.ipynb',
#   'name': 'Untitled.ipynb',
#   'type': 'notebook',
#   'kernel': {'id': '63a298dc-5c4f-46af-9fb1-0f01f746ea57',
#    'name': 'python3',
#    'last_activity': '2020-05-27T16:56:31.301723Z',
#    'execution_state': 'idle',
#    'connections': 1},
#   'notebook': {'path': 'examples/Untitled.ipynb', 'name': 'Untitled.ipynb'}}]

# %%
app.sessions.current_session
# Out:
# {}

# %% [markdown]
# # Session Manager

# %%
# %pip install -q ipylab

# %%
import ipylab

# %%
app = ipylab.JupyterFrontEnd()

# %% [markdown]
# ## Show all sessions from the global `SessionManager` instance

# %%
app.all_sessions

# %% [markdown]
# ## Show current session

# %%
app.current_session

# %% [markdown]
# ## Example: Create Console with current session
# The following two commands should both create a console panel sharing the same `session` as the current notebook.

# %%
app.execute_command("console:create", **app.current_session)

# %% [markdown]
# ## Create a new Notebook
#
# Create a new notebook and use the connection to interact with the notebook directly.

# %%
app.current_session

# %%
t = app.execute_command("notebook:create-new", transform=ipylab.TransformMode.connection)

# %%
nb = t.result()
nb  # A disposeable connection to the notebook.

# %% [markdown]
# We can use the connection to the notebook to do various actions. Lets list the attributes of the context.

# %%
t = nb.list_attributes("context")

# %%
t.result()

# %%
t = nb.get_attribute(
    "",
    transform={
        "transform": ipylab.TransformMode.advanced,
        "mappings": {"context": ipylab.TransformMode.connection, "sessionContext": ipylab.TransformMode.connection},
    },
)

# %%
mappings = t.result()

# %%
context, session_context = mappings["context"], mappings["sessionContext"]

# %%
t = context.list_attributes()

# %%
t.result()

# %%
t = session_context.list_attributes()

# %%
t.result()

# %%
nb.execute_method("context.rename", "My renamed notebook.ipynb")

# %%
nb.dispose()

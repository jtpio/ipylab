# %% [markdown]
# # Command Registry

# %%
# %pip install -q ipylab

# %% [markdown]
# Note: This notebook should be run one line at a time waiting for each cell to return before running the next cell.

# %%
import asyncio

import ipywidgets as ipw

import ipylab

app = ipylab.JupyterFrontEnd()

# %%
app.version

# %% [markdown]
# ## List all commands

# %%
app.commands.all_commands

# %%
t = app.commands.execute_method("describedBy", "console:inject")

# %%
t.result()

# %% [markdown]
# ## Create a new console

# %%
t = app.execute_command(
    "console:create",
    insertMode="split-right",
    kernelPreference={"id": app.kernelId},
    transform=ipylab.TransformMode.connection,  # Optional
)

# %%
w = t.result()

# %%
w.dispose()

# %% [markdown]
# ## Change the theme

# %%
app.execute_command("apputils:change-theme", theme="JupyterLab Dark")

# %%
app.execute_command("apputils:change-theme", theme="JupyterLab Light")

# %% [markdown]
# ## Add your own command
#
# Let's create a split panel and add a command to toggle the orientation.

# %%
split_panel = ipylab.SplitPanel(children=[ipw.Button(description="Item A"), ipw.Button(description="Item B")])
split_panel.addToShell()

# %% [markdown]
# We now define a function to update the data.

# %%
def toggle_orientation():
    split_panel.orientation = next(iter({"horizontal", "vertical"}.difference((split_panel.orientation,))))
    split_panel.title.label = split_panel.orientation
    return "Data returned from this custom function 'toggle_orientation'"

# %%
toggle_orientation()

# %% [markdown]
# This function will now be called when the JupyterLab command is executed.
#
# > Commands can also custom [icons](./icons.ipynb) in place of `icon_class`.

# %%
t = app.commands.add(
    "swap_orientation",
    execute=toggle_orientation,
    label="Swap orientation",
    icon_class="jp-PythonIcon",
    frontend_transform=ipylab.TransformMode.raw,
)

# %% [markdown]
# Execute it!

# %%
cmd = t.result()

# %%
t = app.execute_command(str(cmd), transform=ipylab.TransformMode.raw, isToggleable=True)

# %% [markdown]
# Notice how the orientation switched?
#
# Also we can get the result from the operation:

# %%
result = t.result()
assert result == "Data returned from this custom function 'toggle_orientation'"  # noqa: S101

# %% [markdown]
# The message has taken the follow steps to get the result:
#
# 1. Python -> JavaScript : execute_command `ipylab command:swap_orientation`
# 2. JavaScript -> Python : _do_operation_for_frontend 'execute' `ipylab command:swap_orientation`
# 3. Python -> JavaScript : Return the result of `ipylab command:swap_orientation`
# 4. JavaScript -> Python : The result of execute_command `ipylab command:swap_orientation`
#
# Also the list of commands gets updated with the newly added command:

# %%
assert str(cmd) in app.commands.all_commands  # noqa: S101

# %% [markdown]
# That's great, but the command doesn't visually show up in the palette yet. So let's add it!

# %% [markdown]
# ## Add the command to the [command palette](https://jupyterlab.readthedocs.io/en/latest/user/commands.html#command-palette)

# %%
t = app.commands.pallet.add(cmd, "Python Commands")

# %%
pc = t.result()
t = pc.list_attributes()

# %%
result = t.result()
result

# %% [markdown]
# Open the command palette (CTRL + SHIFT + C) and the command should show now be visible. Look for `Swap orientation`

# %%
def show_command_pallet():
    # Use a delay to the call so the command pallet remains open.
    asyncio.get_running_loop().call_later(1, app.execute_command, "apputils:activate-command-palette")


show_command_pallet()

# %% [markdown]
# ## Launcher

# %%
t = app.commands.launcher.add(cmd, "My command")

# %%
launcher = t.result()

# %% [markdown]
# Notice that a launcher button exists for this command?

# %%
app.execute_command("launcher:create")

# %%
launcher.dispose()

# %% [markdown]
# There area also handy methods on the command link:
#
# * add_to_command_pallet
# * add launcher
#
# As a bonus, these will dispose of the items when the command link is closed.

# %%
t = cmd.add_launcher("My command2")

# %%
launcher2 = t.result()

# %%
launcher2.dispose()

# %% [markdown]
# ## Configure a command
#
# The command can be configured using the connection returned when adding the command.

# %%
ipylab.commands.CommandOptions.__annotations__

# %%
t = cmd.configure(isEnabled=False)

# %% [markdown]
# Notice the command is not in the pallet.

# %%
show_command_pallet()

# %%
# The config
t.result()

# %%
t = cmd.configure(isEnabled=True)

# %%
show_command_pallet()

# %% [markdown]
# Again the command is again available in the pallet.

# %%
# The config
t.result()

# %% [markdown]
# ## Remove a command
#
# To remove a command that was previously added:

# %%
assert str(cmd) not in app.commands.all_commands  # noqa: S101

# %%
app.commands.remove_command("swap_orientation")
# or just call dispose on the connection.
cmd.dispose()

# %%
assert str(cmd) not in app.commands.all_commands  # noqa: S101

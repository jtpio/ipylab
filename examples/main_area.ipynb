# %% [markdown]
# # Main area
# `MainArea` is the place to host an app. It works differntly to `Panel`, `SplitPanel` and boxes in a few important ways:
# * It doesn't accept children, rather, it has `content` which should be either a `Panel` or `SplitPanel` (but the content can be changed when calling the `load` method).
# * It can be `loaded` or `unloaded` from the shell by calling `load` and `unload` respectively.
# * It maintains a `context` to the kernel in which it is running making it possible to maintin comms without needing a loaded notebook.
# * A console to the same kernel can be opened using `load_console` and `unload_console`.

# %%
# %pip install -q ipylab

# %%
import ipylab
import ipywidgets as ipw

# %%
ma = ipylab.MainArea(name='My main area')

# %%
ma.loaded
# Out:
# True

# %%
some_html = ipw.HTML("This children can be swapped out as required.")
console_button = ipw.Button(description='Toggle console')
def on_click(b):
    ma.load_console() if not ma.console_loaded else ma.unload_console()
console_button.on_click(on_click)
close_button = ipw.Button(description='Close')
close_button.on_click(lambda b: ma.close())
ma.content.children = [some_html, console_button, close_button]

# %%
ma.content.title.label = "My app's title"

# %%
ma.load(area='main')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ma.load(area='main')
#
# File ~/ipylab/ipylab/main_area.py:101, in MainArea.load(self, content, area, activate, mode, rank, ref, class_name)
#      99 if content:
#     100     self.set_trait("content", content)
# --> 101 return self.schedule_operation(
#     102     "load",
#     103     area=area,
#     104     options={"mode": mode, "rank": rank, "activate": activate, "ref": pack(ref)},
#     105     className=class_name,
#     106 )
#
# File ~/ipylab/ipylab/asyncwidget.py:149, in AsyncWidgetBase.schedule_operation(self, operation, callback, **kwgs)
#     146 def schedule_operation(
#     147     self, operation: str, *, callback: Callable[[any], None | Coroutine] = None, **kwgs
#     148 ) -> asyncio.Task:
# --> 149     self._check_closed()
#     150     if not operation or not isinstance(operation, str):
#     151         raise ValueError(f"Invalid {operation=}")
#
# File ~/ipylab/ipylab/asyncwidget.py:121, in AsyncWidgetBase._check_closed(self)
#     119 def _check_closed(self):
#     120     if self.closed:
# --> 121         raise RuntimeError(f"This object is closed {self}")
#
# RuntimeError: This object is closed <MainArea at 140640724550720>

# %%
t = ma.load_console(name='my console',mode=ipylab.InsertMode.merge_left, path='my own path')

# %%
t.result()

# %%
ma.unload()
